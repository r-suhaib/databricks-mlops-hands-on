# %%
from src.platform.configuration_catalog import (
    create_configuration_record
)

catalog_df = spark.createDataFrame(
    create_configuration_record()
)

(
    catalog_df.write
    .mode("append")
    .saveAsTable(
        "tep_anomaly.served.configuration_catalog"
    )
)

display(
    spark.table(
        "tep_anomaly.served.configuration_catalog"
    )
)

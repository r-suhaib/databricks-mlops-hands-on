# %%
# %sql
CREATE TABLE IF NOT EXISTS
tep_anomaly.served.configuration_catalog
(
    model_name STRING,
    config_file STRING,
    source_table STRING,
    registry_model STRING,
    environment STRING,
    schedule STRING,
    active_flag BOOLEAN
)
USING DELTA;

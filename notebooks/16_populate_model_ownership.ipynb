# %%
from src.platform.model_ownership import (
    create_ownership_record
)

ownership_df = spark.createDataFrame(
    create_ownership_record()
)

(
    ownership_df.write
    .mode("append")
    .saveAsTable(
        "tep_anomaly.served.model_ownership"
    )
)

display(
    spark.table(
        "tep_anomaly.served.model_ownership"
    )
)

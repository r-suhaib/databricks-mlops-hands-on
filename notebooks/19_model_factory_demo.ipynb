# %%
from src.platform.model_factory import (
    discover_model_configs
)

configs = (
    discover_model_configs()
)

print(
    "Discovered Configurations:"
)

for config in configs:

    print(config)

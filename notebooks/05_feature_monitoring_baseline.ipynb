# %%
from src.monitoring.feature_monitor import (
    calculate_feature_statistics
)

# %%
df = tep_anomaly.served.training_base

monitored_features = [
    "xmeas_1",
    "xmeas_2",
    "xmeas_3",
    "xmeas_1_delta1",
    "xmeas_2_delta1",
    "xmeas_3_delta1"
]

# %%
stats = calculate_feature_statistics(
    df,
    monitored_features
)

print(stats)

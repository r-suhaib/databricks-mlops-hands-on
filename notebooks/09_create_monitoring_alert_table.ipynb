# %%
# %sql
CREATE TABLE IF NOT EXISTS
tep_anomaly.served.monitoring_alerts
(
    alert_timestamp TIMESTAMP,
    feature_name STRING,
    drift_percent DOUBLE,
    alert_type STRING,
    alert_message STRING
)
USING DELTA
